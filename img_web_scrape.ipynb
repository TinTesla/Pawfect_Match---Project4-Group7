# %% [markdown]
# ## Read in dataset to obtain the list of breeds

# %%
#import pandas to read in csv 
import pandas as pd

# %%
file_path = "akc-data-latest.csv"
df_dogbreeds = pd.read_csv(file_path)

df_dogbreeds.head(10)
# Out:
#                    Unnamed: 0  \
# 0               Affenpinscher
# 1                Afghan Hound
# 2            Airedale Terrier
# 3                       Akita
# 4            Alaskan Malamute
# 5            American Bulldog
# 6  American English Coonhound
# 7         American Eskimo Dog
# 8           American Foxhound
# 9   American Hairless Terrier
#
#                                          description  \
# 0  The Affen’s apish look has been described many...
# 1  The Afghan Hound is an ancient breed, his whol...
# 2  The Airedale Terrier is the largest of all ter...
# 3  Akitas are burly, heavy-boned spitz-type dogs ...
# 4  The Alaskan Malamute stands 23 to 25 inches at...
# 5  The American Bulldog is a descendant of the En...
# 6  Standing as high as 26 inches at the shoulder,...
# 7  The American Eskimo Dog comes in three sizes—s...
# 8  American Foxhounds are sleek, rangy hunters kn...
# 9  The American Hairless Terrier stands between 1...
#
#                                  temperament popularity  min_height  \
# 0        Confident, Famously Funny, Fearless        148       22.86
# 1  Dignified, Profoundly Loyal, Aristocratic        113       63.50
# 2               Friendly, Clever, Courageous         60       58.42
# 3    Courageous, Dignified, Profoundly Loyal         47       60.96
# 4               Affectionate, Loyal, Playful         58       58.42
# 5                      Loyal, Self-Confident        NaN       50.80
# 6                    Sweet, Mellow, Sociable        175       58.42
# 7                      Playful, Perky, Smart        122       22.86
# 8    Independent, Easy-Going, Sweet-Tempered        186       53.34
# 9                  Energetic, Alert, Curious        136       30.48
#
#    max_height  min_weight  max_weight  min_expectancy  max_expectancy  ...  \
# 0       29.21    3.175147    4.535924            12.0            15.0  ...
# 1       68.58   22.679619   27.215542            12.0            15.0  ...
# 2       58.42   22.679619   31.751466            11.0            14.0  ...
# 3       71.12   31.751466   58.967008            10.0            13.0  ...
# 4       63.50   34.019428   38.555351            10.0            14.0  ...
# 5       63.50   27.215542   45.359237            10.0            12.0  ...
# 6       66.04   20.411657   29.483504            11.0            12.0  ...
# 7       48.26    2.721554   15.875733            13.0            15.0  ...
# 8       63.50   27.215542   31.751466            11.0            13.0  ...
# 9       40.64    5.443108    7.257478            14.0            16.0  ...
#
#   grooming_frequency_value  grooming_frequency_category shedding_value  \
# 0                      0.6    2-3 Times a Week Brushing            0.6
# 1                      0.8               Daily Brushing            0.2
# 2                      0.6    2-3 Times a Week Brushing            0.4
# 3                      0.8               Daily Brushing            0.6
# 4                      0.6    2-3 Times a Week Brushing            0.6
# 5                      0.2        Occasional Bath/Brush            0.6
# 6                      0.2        Occasional Bath/Brush            0.4
# 7                      0.4              Weekly Brushing            0.6
# 8                      0.2        Occasional Bath/Brush            0.6
# 9                      NaN                          NaN            NaN
#
#    shedding_category energy_level_value  energy_level_category  \
# 0           Seasonal                0.6       Regular Exercise
# 1         Infrequent                0.8              Energetic
# 2         Occasional                0.6       Regular Exercise
# 3           Seasonal                0.8              Energetic
# 4           Seasonal                0.8              Energetic
# 5           Seasonal                0.8              Energetic
# 6         Occasional                0.8              Energetic
# 7           Seasonal                0.8              Energetic
# 8           Seasonal                0.8              Energetic
# 9                NaN                NaN                    NaN
#
#   trainability_value  trainability_category demeanor_value  demeanor_category
# 0                0.8          Easy Training            1.0           Outgoing
# 1                0.2        May be Stubborn            0.2         Aloof/Wary
# 2                1.0        Eager to Please            0.8           Friendly
# 3                1.0        Eager to Please            0.6   Alert/Responsive
# 4                0.4            Independent            0.8           Friendly
# 5                0.6              Agreeable            0.6   Alert/Responsive
# 6                0.6              Agreeable            0.6   Alert/Responsive
# 7                1.0        Eager to Please            1.0           Outgoing
# 8                0.4            Independent            0.8           Friendly
# 9                NaN                    NaN            NaN                NaN
#
# [10 rows x 21 columns]

# %%
#check datatypes of cols
df_dogbreeds.dtypes
# Out:
# Unnamed: 0                      object
# description                     object
# temperament                     object
# popularity                      object
# min_height                     float64
# max_height                     float64
# min_weight                     float64
# max_weight                     float64
# min_expectancy                 float64
# max_expectancy                 float64
# group                           object
# grooming_frequency_value       float64
# grooming_frequency_category     object
# shedding_value                 float64
# shedding_category               object
# energy_level_value             float64
# energy_level_category           object
# trainability_value             float64
# trainability_category           object
# demeanor_value                 float64
# demeanor_category               object
# dtype: object

# %%
#rename unnamed: 0 column 
df_dogbreeds = df_dogbreeds.rename(columns={'Unnamed: 0': 'breeds'})
df_dogbreeds
# Out:
#                 breeds                                        description  \
# 0        Affenpinscher  The Affen’s apish look has been described many...
# 1         Afghan Hound  The Afghan Hound is an ancient breed, his whol...
# 2     Airedale Terrier  The Airedale Terrier is the largest of all ter...
# 3                Akita  Akitas are burly, heavy-boned spitz-type dogs ...
# 4     Alaskan Malamute  The Alaskan Malamute stands 23 to 25 inches at...
# ..                 ...                                                ...
# 272  Wirehaired Vizsla  WVs are close relatives of Vizslas but a disti...
# 273     Working Kelpie  The overall appearance of the Working Kelpie i...
# 274     Xoloitzcuintli  The Xoloitzcuintli (show-low-eats-queen-tlee) ...
# 275     Yakutian Laika  For centuries the Yakutian Laika was an irrepl...
# 276  Yorkshire Terrier  The Yorkshire Terrier is a compact, toy-size t...
#
#                                    temperament popularity  min_height  \
# 0          Confident, Famously Funny, Fearless        148       22.86
# 1    Dignified, Profoundly Loyal, Aristocratic        113       63.50
# 2                 Friendly, Clever, Courageous         60       58.42
# 3      Courageous, Dignified, Profoundly Loyal         47       60.96
# 4                 Affectionate, Loyal, Playful         58       58.42
# ..                                         ...        ...         ...
# 272                   Gentle, Loyal, Trainable        167       54.61
# 273                  Alert, Eager, Intelligent        NaN       48.26
# 274                         Loyal, Alert, Calm        140       25.40
# 275          Affectionate, Intelligent, Active        NaN       53.34
# 276         Affectionate, Sprightly, Tomboyish         10       17.78
#
#      max_height  min_weight  max_weight  min_expectancy  max_expectancy  ...  \
# 0         29.21    3.175147    4.535924            12.0            15.0  ...
# 1         68.58   22.679619   27.215542            12.0            15.0  ...
# 2         58.42   22.679619   31.751466            11.0            14.0  ...
# 3         71.12   31.751466   58.967008            10.0            13.0  ...
# 4         63.50   34.019428   38.555351            10.0            14.0  ...
# ..          ...         ...         ...             ...             ...  ...
# 272       63.50   20.411657   29.483504            12.0            14.0  ...
# 273       63.50   12.700586   27.215542            12.0            15.0  ...
# 274       58.42    4.535924   24.947580            13.0            18.0  ...
# 275       58.42   18.143695   24.947580            10.0            12.0  ...
# 276       20.32    3.175147    3.175147            11.0            15.0  ...
#
#     grooming_frequency_value  grooming_frequency_category shedding_value  \
# 0                        0.6    2-3 Times a Week Brushing            0.6
# 1                        0.8               Daily Brushing            0.2
# 2                        0.6    2-3 Times a Week Brushing            0.4
# 3                        0.8               Daily Brushing            0.6
# 4                        0.6    2-3 Times a Week Brushing            0.6
# ..                       ...                          ...            ...
# 272                      0.2        Occasional Bath/Brush            0.6
# 273                      0.2        Occasional Bath/Brush            0.6
# 274                      0.2        Occasional Bath/Brush            0.2
# 275                      0.4              Weekly Brushing            0.6
# 276                      1.0       Specialty/Professional            0.2
#
#      shedding_category energy_level_value  energy_level_category  \
# 0             Seasonal                0.6       Regular Exercise
# 1           Infrequent                0.8              Energetic
# 2           Occasional                0.6       Regular Exercise
# 3             Seasonal                0.8              Energetic
# 4             Seasonal                0.8              Energetic
# ..                 ...                ...                    ...
# 272           Seasonal                0.8              Energetic
# 273           Seasonal                0.8              Energetic
# 274         Infrequent                0.8              Energetic
# 275           Seasonal                0.8              Energetic
# 276         Infrequent                0.6       Regular Exercise
#
#     trainability_value  trainability_category demeanor_value  \
# 0                  0.8          Easy Training            1.0
# 1                  0.2        May be Stubborn            0.2
# 2                  1.0        Eager to Please            0.8
# 3                  1.0        Eager to Please            0.6
# 4                  0.4            Independent            0.8
# ..                 ...                    ...            ...
# 272                0.6              Agreeable            0.6
# 273                0.4            Independent            0.6
# 274                0.6              Agreeable            0.6
# 275                0.2        May be Stubborn            0.4
# 276                0.2        May be Stubborn            0.8
#
#            demeanor_category
# 0                   Outgoing
# 1                 Aloof/Wary
# 2                   Friendly
# 3           Alert/Responsive
# 4                   Friendly
# ..                       ...
# 272         Alert/Responsive
# 273         Alert/Responsive
# 274         Alert/Responsive
# 275  Reserved with Strangers
# 276                 Friendly
#
# [277 rows x 21 columns]

# %%
#convert datatype of breeds col to string
df_dogbreeds['breeds'] = df_dogbreeds.breeds.astype('string')
df_dogbreeds.dtypes
# Out:
# breeds                          string
# description                     object
# temperament                     object
# popularity                      object
# min_height                     float64
# max_height                     float64
# min_weight                     float64
# max_weight                     float64
# min_expectancy                 float64
# max_expectancy                 float64
# group                           object
# grooming_frequency_value       float64
# grooming_frequency_category     object
# shedding_value                 float64
# shedding_category               object
# energy_level_value             float64
# energy_level_category           object
# trainability_value             float64
# trainability_category           object
# demeanor_value                 float64
# demeanor_category               object
# dtype: object

# %%
# get breeds into a list to be used for webscraping
dog_breeds = df_dogbreeds['breeds']
dog_breeds
# Out:
# 0          Affenpinscher
# 1           Afghan Hound
# 2       Airedale Terrier
# 3                  Akita
# 4       Alaskan Malamute
#              ...
# 272    Wirehaired Vizsla
# 273       Working Kelpie
# 274       Xoloitzcuintli
# 275       Yakutian Laika
# 276    Yorkshire Terrier
# Name: breeds, Length: 277, dtype: string

# %%
# make variables compatible with website url params (replace space with hyphen)
breed_list =[]
for dog in dog_breeds:
    dog = dog.replace(' ','-')
    breed_list.append(dog)
print(len(breed_list))
# Out:
# 277

# %%
breed_list[:10]
# Out:
# ['Affenpinscher',
#  'Afghan-Hound',
#  'Airedale-Terrier',
#  'Akita',
#  'Alaskan-Malamute',
#  'American-Bulldog',
#  'American-English-Coonhound',
#  'American-Eskimo-Dog',
#  'American-Foxhound',
#  'American-Hairless-Terrier']

# %% [markdown]
# ## Webscrape AKC for images of breeds in list

# %%
# Import Splinter and BeautifulSoup
#!pip3 install splinter
from splinter import Browser
from bs4 import BeautifulSoup as soup

# %%
#open browser
browser = Browser('chrome')

# %%
#create url for initial setup & go to site
url = 'https://www.akc.org/dog-breeds/'
browser.visit(url)

# %%
# ------------------ TEST ---------------
# way 1: finds more than one pic ?
# and image is a large list
#image = img_soup.find_all('div', class_='breed-page__hero__gallery__image-wrapper')

#import bs4
#for im in image:
#    img_list =[]
#    if im.img:
#        if im.img.has_attr('src'):
#            img_list.append(im.img['src'])
#            print(img_list) #gets link of pic
# Out:
# <div class="breed-page__hero__gallery__image-wrapper" style="width: 100%; display: inline-block;" tabindex="-1"><img alt="Chihuahua sitting in dramatic lighting." class="lozad" data-fully-loaded="true" data-loaded="true" data-src="https://www.akc.org/wp-content/uploads/2017/11/Chihuahua-sitting-in-dramatic-lighting.jpg" src="https://www.akc.org/wp-content/uploads/2017/11/Chihuahua-sitting-in-dramatic-lighting.jpg"/></div>

# %%
# ------------------ TEST ---------------
# way 2: grabs one variable in images
#images = img_soup.find_all('li', class_='slick-active')
#images
# Out:
# [<li class="slick-active"><span><img class="breed-page__gallery-image lozad" data-src="https://www.akc.org/wp-content/uploads/2017/11/Chihuahua-standing-in-three-quarter-view.jpg"/></span></li>,
#  <li class="slick-active"><button>1</button></li>,
#  <li class="slick-active"><button>1</button></li>]

# %%
# ------------------ TEST ---------------
#import bs4
#image_list = []
#for im in images:
#    if im.img:
#        if im.img.has_attr('data-src'):
#            img_updated = im.img['data-src'].replace("'","")
#            image_list.append(img_updated)
#print(img_updated)
#print(image_list[0])
# Out:
# https://www.akc.org/wp-content/uploads/2017/11/Chihuahua-standing-in-three-quarter-view.jpg
# https://www.akc.org/wp-content/uploads/2017/11/Chihuahua-standing-in-three-quarter-view.jpg

# %%
# create an empty list that will be used for df
db_img = []

# %%
# set up loop for all dogs in dataset
for doggo in breed_list:
    # create specific url
    concat = url + doggo 
    
    # visit webpage
    browser.visit(concat)
    html = browser.html
    img_soup = soup(html, 'html.parser')
    
    # go through html txt to find wrap where img lives
    images = img_soup.find_all('li', class_='slick-active')
    
    # append image to a list
    for im in images:
        if im.img:
            if im.img.has_attr('data-src'):
                img_updated = im.img['data-src'].replace("'","")
            
    # make a dict
    doggies = {
        'Breed': doggo,
        'Img_Link': img_updated
    }
    # append dict to df list 
    db_img.append(doggies)
    # loop to next dog

# %%
# check to see if loop worked
db_img[:10]
# Out:
# [{'Breed': 'Affenpinscher',
#   'Img_Link': 'https://www.akc.org/wp-content/uploads/2017/11/Affenpinscher-running-outdoors.jpg'},
#  {'Breed': 'Afghan-Hound',
#   'Img_Link': 'https://s3.amazonaws.com/cdn-origin-etr.akc.org/wp-content/uploads/2017/11/02151216/Afghan-Hound-standing-in-a-garden.jpg'},
#  {'Breed': 'Airedale-Terrier',
#   'Img_Link': 'https://s3.amazonaws.com/cdn-origin-etr.akc.org/wp-content/uploads/2017/11/02165956/Airedale-Terrier-standing-stacked-outdoors.jpg'},
#  {'Breed': 'Akita',
#   'Img_Link': 'https://s3.amazonaws.com/cdn-origin-etr.akc.org/wp-content/uploads/2017/11/06154034/Akita-standing-outdoors-in-the-summer.jpg'},
#  {'Breed': 'Alaskan-Malamute',
#   'Img_Link': 'https://s3.amazonaws.com/cdn-origin-etr.akc.org/wp-content/uploads/2017/11/09151144/Alaskan-Malamute-standing-in-the-grass1.jpg'},
#  {'Breed': 'American-Bulldog',
#   'Img_Link': 'https://www.akc.org/wp-content/uploads/2020/01/American-Bulldog-standing-in-three-quarter-view.jpg'},
#  {'Breed': 'American-English-Coonhound',
#   'Img_Link': 'https://s3.amazonaws.com/cdn-origin-etr.akc.org/wp-content/uploads/2017/11/12133501/American-English-Coonhound-howling-in-a-field1.jpg'},
#  {'Breed': 'American-Eskimo-Dog',
#   'Img_Link': 'https://s3.amazonaws.com/cdn-origin-etr.akc.org/wp-content/uploads/2017/11/12153852/American-Eskimo-Dog-standing-in-the-grass-in-bright-sunlight.jpg'},
#  {'Breed': 'American-Foxhound',
#   'Img_Link': 'https://www.akc.org/wp-content/uploads/2018/06/american-foxhound-pair-looking-up.jpg'},
#  {'Breed': 'American-Hairless-Terrier',
#   'Img_Link': 'https://www.akc.org/wp-content/uploads/2017/11/American-Hairless-Terrier-standing-in-the-grass-on-lead.jpg'}]

# %%
# exit browser
browser.quit()

# %%
# create dataframe
breed_img_df = pd.DataFrame(db_img)

# %%
breed_img_df.head()
# Out:
#               Breed                                           Img_Link
# 0     Affenpinscher  https://www.akc.org/wp-content/uploads/2017/11...
# 1      Afghan-Hound  https://s3.amazonaws.com/cdn-origin-etr.akc.or...
# 2  Airedale-Terrier  https://s3.amazonaws.com/cdn-origin-etr.akc.or...
# 3             Akita  https://s3.amazonaws.com/cdn-origin-etr.akc.or...
# 4  Alaskan-Malamute  https://s3.amazonaws.com/cdn-origin-etr.akc.or...

# %%
# make sure no null values
breed_img_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 277 entries, 0 to 276
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Breed     277 non-null    object
#  1   Img_Link  277 non-null    object
# dtypes: object(2)
# memory usage: 4.5+ KB

# %%
# make sure 277 unique
len(breed_img_df['Img_Link'].unique())
# Out:
# 269

# %%
# find which breeds dont have correct imgs
dup = breed_img_df.duplicated(subset=['Img_Link'])
i = 0;
dup_list = []
for n in dup:
    if(n):
        dup_list.append(i)
    i = i + 1
print(dup_list)
# Out:
# [79, 122, 160, 189, 238, 239, 249, 261]

# %%
need_dog_img = breed_img_df.iloc[dup_list,0]
need_dog_img
# Out:
# 79                Cirneco-dell’Etna
# 122    Grand-Basset-Griffon-Vendéen
# 160                         Löwchen
# 189    Petit-Basset-Griffon-Vendéen
# 238                 Slovensky-Kopov
# 239     Small-Munsterlander-Pointer
# 249                Swedish-Lapphund
# 261       Treeing-Tennessee-Brindle
# Name: Breed, dtype: object

# %%
# read dataframe into csv
breed_img_df.to_csv('images4breeds.csv')
